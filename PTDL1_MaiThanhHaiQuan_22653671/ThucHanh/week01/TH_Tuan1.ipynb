# %% [markdown]
# Tiến hành tải dữ liệu vào chương trình ứng dụng Python và giải quyết vấn đề “Missing
# header in the csv file”

# %%
import pandas as pd
column_name = ["Id","Name","Age","Weight","m0006","m0612","m1218","f0006","f0612","f1218"]
df = pd.read_csv('patient_heart_rate.csv', names=column_name)

# %%
df
# Out:
#       Id            Name   Age      Weight m0006 m0612 m1218 f0006 f0612 f1218
# 0    1.0    Mickéy Mousé  56.0       70kgs    72    69    71     -     -     -
# 1    2.0     Donald Duck  34.0   154.89lbs     -     -     -    85    84    76
# 2    3.0      Mini Mouse  16.0         NaN     -     -     -    65    69    72
# 3    4.0  Scrooge McDuck   NaN       78kgs    78    79    72     -     -     -
# 4    5.0    Pink Panther  54.0  198.658lbs     -     -     -    69   NaN    75
# 5    6.0     Huey McDuck  52.0      189lbs     -     -     -    68    75    72
# 6    7.0    Dewey McDuck  19.0       56kgs     -     -     -    71    78    75
# 7    8.0      Scööpy Doo  32.0       78kgs    78    76    75     -     -     -
# 8    NaN             NaN   NaN         NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9    NaN             NaN   NaN         NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10   9.0     Huey McDuck  52.0      189lbs     -     -     -    68    75    72
# 11  10.0    Louie McDuck  12.0       45kgs     -     -     -    92    95    87
# 12  11.0       Henry Nam   NaN       60kgs    78    75    72     -     -     -
# 13  12.0     Michel Long  34.0         NaN    65    67    55     -     -     -
# 14  13.0      Tana Ricky   NaN         NaN     -     -     -    68    72    70
# 15  14.0        UniLever   NaN         NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 16  15.0             NaN  52.0      180lbs     -     -     -    68    75    72

# %%
df.head(10)
# Out:
#     Id            Name   Age      Weight m0006 m0612 m1218 f0006 f0612 f1218
# 0  1.0    Mickéy Mousé  56.0       70kgs    72    69    71     -     -     -
# 1  2.0     Donald Duck  34.0   154.89lbs     -     -     -    85    84    76
# 2  3.0      Mini Mouse  16.0         NaN     -     -     -    65    69    72
# 3  4.0  Scrooge McDuck   NaN       78kgs    78    79    72     -     -     -
# 4  5.0    Pink Panther  54.0  198.658lbs     -     -     -    69   NaN    75
# 5  6.0     Huey McDuck  52.0      189lbs     -     -     -    68    75    72
# 6  7.0    Dewey McDuck  19.0       56kgs     -     -     -    71    78    75
# 7  8.0      Scööpy Doo  32.0       78kgs    78    76    75     -     -     -
# 8  NaN             NaN   NaN         NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9  NaN             NaN   NaN         NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %% [markdown]
# Xử lý vấn đề một cột lưu hỗn hợp nhiều dữ liệu, ở đây là cột “Name” chứa bao gồm
# “Firstname” và “Lastname”, giải pháp là ta sẽ tách ra làm 2 cột

# %%
df[['Firstname','Lastname']] = df['Name'].str.split(expand=True)
df = df.drop('Name', axis=1)

# %%
df.head(5)
# Out:
#     Id   Age      Weight m0006 m0612 m1218 f0006 f0612 f1218 Firstname  \
# 0  1.0  56.0       70kgs    72    69    71     -     -     -    Mickéy
# 1  2.0  34.0   154.89lbs     -     -     -    85    84    76    Donald
# 2  3.0  16.0         NaN     -     -     -    65    69    72      Mini
# 3  4.0   NaN       78kgs    78    79    72     -     -     -   Scrooge
# 4  5.0  54.0  198.658lbs     -     -     -    69   NaN    75      Pink
#
#   Lastname
# 0    Mousé
# 1     Duck
# 2    Mouse
# 3   McDuck
# 4  Panther

# %% [markdown]
# Cột Weight có vấn đề về không thống nhất các đơn vị đo lường trong dữ liệu. Ta sẽ
# chuyển các đơn vị về thành đơn vị chuẩn “kg”

# %%
weight = df['Weight']
for i in range(0, len(weight)):
    x = str(weight[i])
    if 'lbs' in x[-3:]:
        x = x[:-3:]
        float_x = float(x)
        y = int(float_x/2.2)
        weight[i]=y
    if 'kgs' in x[-3:]:
        x = x[:-3:]
        float_x = float(x)
        weight[i]=x
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\2017609309.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weight[i]=x
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\2017609309.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weight[i]=y
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\2017609309.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weight[i]=x
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\2017609309.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weight[i]=y
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\2017609309.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weight[i]=y
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\2017609309.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weight[i]=x
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\2017609309.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weight[i]=x
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\2017609309.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weight[i]=y
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\2017609309.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weight[i]=x
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\2017609309.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weight[i]=x
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\2017609309.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weight[i]=y

# %%
df.rename(columns={'Weight':"Weight_kgs"},inplace=True)

# %%
df
# Out:
#       Id   Age Weight_kgs m0006 m0612 m1218 f0006 f0612 f1218 Firstname  \
# 0    1.0  56.0         70    72    69    71     -     -     -    Mickéy
# 1    2.0  34.0         70     -     -     -    85    84    76    Donald
# 2    3.0  16.0        NaN     -     -     -    65    69    72      Mini
# 3    4.0   NaN         78    78    79    72     -     -     -   Scrooge
# 4    5.0  54.0         90     -     -     -    69   NaN    75      Pink
# 5    6.0  52.0         85     -     -     -    68    75    72      Huey
# 6    7.0  19.0         56     -     -     -    71    78    75     Dewey
# 7    8.0  32.0         78    78    76    75     -     -     -    Scööpy
# 8    NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN
# 9    NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN
# 10   9.0  52.0         85     -     -     -    68    75    72      Huey
# 11  10.0  12.0         45     -     -     -    92    95    87     Louie
# 12  11.0   NaN         60    78    75    72     -     -     -     Henry
# 13  12.0  34.0        NaN    65    67    55     -     -     -    Michel
# 14  13.0   NaN        NaN     -     -     -    68    72    70      Tana
# 15  14.0   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN  UniLever
# 16  15.0  52.0         81     -     -     -    68    75    72       NaN
#
#    Lastname
# 0     Mousé
# 1      Duck
# 2     Mouse
# 3    McDuck
# 4   Panther
# 5    McDuck
# 6    McDuck
# 7       Doo
# 8       NaN
# 9       NaN
# 10   McDuck
# 11   McDuck
# 12      Nam
# 13     Long
# 14    Ricky
# 15     None
# 16      NaN

# %% [markdown]
# Vấn đề về xuất hiện dòng dữ liệu rỗng (không có giá trị: NaN). Giải pháp có thể đưa ra là
# xóa bỏ

# %%
df.dropna(how='all',inplace=True)

# %%
df
# Out:
#       Id   Age Weight_kgs m0006 m0612 m1218 f0006 f0612 f1218 Firstname  \
# 0    1.0  56.0         70    72    69    71     -     -     -    Mickéy
# 1    2.0  34.0         70     -     -     -    85    84    76    Donald
# 2    3.0  16.0        NaN     -     -     -    65    69    72      Mini
# 3    4.0   NaN         78    78    79    72     -     -     -   Scrooge
# 4    5.0  54.0         90     -     -     -    69   NaN    75      Pink
# 5    6.0  52.0         85     -     -     -    68    75    72      Huey
# 6    7.0  19.0         56     -     -     -    71    78    75     Dewey
# 7    8.0  32.0         78    78    76    75     -     -     -    Scööpy
# 10   9.0  52.0         85     -     -     -    68    75    72      Huey
# 11  10.0  12.0         45     -     -     -    92    95    87     Louie
# 12  11.0   NaN         60    78    75    72     -     -     -     Henry
# 13  12.0  34.0        NaN    65    67    55     -     -     -    Michel
# 14  13.0   NaN        NaN     -     -     -    68    72    70      Tana
# 15  14.0   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN  UniLever
# 16  15.0  52.0         81     -     -     -    68    75    72       NaN
#
#    Lastname
# 0     Mousé
# 1      Duck
# 2     Mouse
# 3    McDuck
# 4   Panther
# 5    McDuck
# 6    McDuck
# 7       Doo
# 10   McDuck
# 11   McDuck
# 12      Nam
# 13     Long
# 14    Ricky
# 15     None
# 16      NaN

# %% [markdown]
# Có nhiều dòng dữ liệu bị trùng lắp thông tin hoàn toàn[fullname, lastname, age,
# weight_kgs,....], giải pháp đưa ra là chỉ giữ lại một dòng dữ liệu, tuy nhiên giải pháp phải
# dựa trên nghiệp vụ của tập dữ liệu và quan sát của người xử lý.

# %%
df = df.drop_duplicates(subset=['Firstname','Lastname','Age','Weight_kgs'])

# %%
df
# Out:
#       Id   Age Weight_kgs m0006 m0612 m1218 f0006 f0612 f1218 Firstname  \
# 0    1.0  56.0         70    72    69    71     -     -     -    Mickéy
# 1    2.0  34.0         70     -     -     -    85    84    76    Donald
# 2    3.0  16.0        NaN     -     -     -    65    69    72      Mini
# 3    4.0   NaN         78    78    79    72     -     -     -   Scrooge
# 4    5.0  54.0         90     -     -     -    69   NaN    75      Pink
# 5    6.0  52.0         85     -     -     -    68    75    72      Huey
# 6    7.0  19.0         56     -     -     -    71    78    75     Dewey
# 7    8.0  32.0         78    78    76    75     -     -     -    Scööpy
# 11  10.0  12.0         45     -     -     -    92    95    87     Louie
# 12  11.0   NaN         60    78    75    72     -     -     -     Henry
# 13  12.0  34.0        NaN    65    67    55     -     -     -    Michel
# 14  13.0   NaN        NaN     -     -     -    68    72    70      Tana
# 15  14.0   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN  UniLever
# 16  15.0  52.0         81     -     -     -    68    75    72       NaN
#
#    Lastname
# 0     Mousé
# 1      Duck
# 2     Mouse
# 3    McDuck
# 4   Panther
# 5    McDuck
# 6    McDuck
# 7       Doo
# 11   McDuck
# 12      Nam
# 13     Long
# 14    Ricky
# 15     None
# 16      NaN

# %% [markdown]
# Xuất hiện dữ liệu bị ảnh hưởng bởi lỗi non-ASCII, không định dạng ASCII. Giải pháp:
# Tùy vào nghiệp vụ ta có thể: xóa dữ liệu tại đó, thay thế bằng dữ liệu khác hoặc thay
# bằng việc đánh dấu bằng một kí tự khác (ví dụ: ‘warning’)

# %%
df.Firstname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
df.Lastname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
print(df)
# Out:
#       Id   Age Weight_kgs m0006 m0612 m1218 f0006 f0612 f1218 Firstname  \
# 0    1.0  56.0         70    72    69    71     -     -     -     Micky
# 1    2.0  34.0         70     -     -     -    85    84    76    Donald
# 2    3.0  16.0        NaN     -     -     -    65    69    72      Mini
# 3    4.0   NaN         78    78    79    72     -     -     -   Scrooge
# 4    5.0  54.0         90     -     -     -    69   NaN    75      Pink
# 5    6.0  52.0         85     -     -     -    68    75    72      Huey
# 6    7.0  19.0         56     -     -     -    71    78    75     Dewey
# 7    8.0  32.0         78    78    76    75     -     -     -      Scpy
# 11  10.0  12.0         45     -     -     -    92    95    87     Louie
# 12  11.0   NaN         60    78    75    72     -     -     -     Henry
# 13  12.0  34.0        NaN    65    67    55     -     -     -    Michel
# 14  13.0   NaN        NaN     -     -     -    68    72    70      Tana
# 15  14.0   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN  UniLever
# 16  15.0  52.0         81     -     -     -    68    75    72       NaN
#
#    Lastname
# 0      Mous
# 1      Duck
# 2     Mouse
# 3    McDuck
# 4   Panther
# 5    McDuck
# 6    McDuck
# 7       Doo
# 11   McDuck
# 12      Nam
# 13     Long
# 14    Ricky
# 15     None
# 16      NaN
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\3758458077.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Firstname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\3758458077.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Firstname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\3758458077.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Lastname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\3758458077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Lastname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)

# %% [markdown]
# “Missing values”, vấn đề này xảy ra tại các cột “Age”, “Weight” và “Heart Rate”. Thiếu
# dữ liệu (dữ liệu không đầy đủ) là vấn đề xảy ra nhiều trong các nguồn dữ liệu do nhiều
# nguyên nhân chủ quan lẫn khách quan. Có một vài giải pháp để xử lý vấn đề này, chủ yếu
# dựa trên kinh nghiệm và nghiệp vụ về tập dữ liệu đó. Một số giải pháp đưa đề xuất từ
# chuyên gia như sau:
# a.  Deletion: Remove records with missing values
# b.  Dummy substitution: Replace missing values with a dummy but valid
# value: e.g.: 0 for numerical values.
# c.  Mean substitution: Replace the missing values with the mean.
# d.  Frequent substitution: Replace the missing values with the most
# frequent item.
# e.  Improve the data collector: Your business folk will talk to the clients
# and inform them about why it is worth fixing the problem with the data
# collector.
# ……
# Thay giá trị thiếu của tuổi bằng giá trị yếu vị.

# %%
# Thay giá trị thiếu của tuổi bằng giá trị yếu vị.
df['Age'].fillna(df['Age'].mode()[0], inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\1489551230.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mode()[0], inplace=True)
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\1489551230.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].fillna(df['Age'].mode()[0], inplace=True)

# %%
# Thay giá trị thiếu của cân nặng bằng giá trị trung vị
df['Weight_kgs'].fillna(df['Weight_kgs'].median(), inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\1767605888.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Weight_kgs'].fillna(df['Weight_kgs'].median(), inplace=True)
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\1767605888.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight_kgs'].fillna(df['Weight_kgs'].median(), inplace=True)

# %% [markdown]
# “Một cột chứa quá nhiều thông tin cần được phân rã”, như trong bài toán này ta thấy
# header “m0006” chứa các nội dung bao gồm: m → male, 0006 ~ 00-06 (lần đo chỉ số
# nhịp tim từ 00h- đến 06h). Còn giá trị thì là kết quả đo nhịp tim.
# Chúng ta sẽ tách nội dung của cột này ra làm 3 cột sau: PulseRate : giá trị nhịp tim, Sex:
# giới tính ( m: male, f: female) và time: thời gian (từ giờ-đến giờ) như sau:

# %%
# Bước 1: Tạo melt dữ liệu để có cột gender_time
df = pd.melt(df, id_vars=['Id', 'Age', 'Weight_kgs', 'Firstname','Lastname'], value_name='PulseRate', var_name='gender_time').sort_values(['Id', 'Age', 'Weight_kgs', 'Firstname','Lastname'])

# %%
df
# Out:
#       Id   Age Weight_kgs Firstname Lastname gender_time PulseRate
# 0    1.0  56.0         70     Micky     Mous       m0006        72
# 14   1.0  56.0         70     Micky     Mous       m0612        69
# 28   1.0  56.0         70     Micky     Mous       m1218        71
# 42   1.0  56.0         70     Micky     Mous       f0006         -
# 56   1.0  56.0         70     Micky     Mous       f0612         -
# ..   ...   ...        ...       ...      ...         ...       ...
# 27  15.0  52.0         81       NaN      NaN       m0612         -
# 41  15.0  52.0         81       NaN      NaN       m1218         -
# 55  15.0  52.0         81       NaN      NaN       f0006        68
# 69  15.0  52.0         81       NaN      NaN       f0612        75
# 83  15.0  52.0         81       NaN      NaN       f1218        72
#
# [84 rows x 7 columns]

# %%
# Bước 2: Tạo data frame tạm là kết quả của việc tách cột gender_time
df_temp = df['gender_time'].str.extract("(\D)(\d+)(\d{2})",expand=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\348379551.py:2: SyntaxWarning: invalid escape sequence '\D'
#   df_temp = df['gender_time'].str.extract("(\D)(\d+)(\d{2})",expand=True)

# %%
df_temp
# Out:
#     0   1   2
# 0   m  00  06
# 14  m  06  12
# 28  m  12  18
# 42  f  00  06
# 56  f  06  12
# .. ..  ..  ..
# 27  m  06  12
# 41  m  12  18
# 55  f  00  06
# 69  f  06  12
# 83  f  12  18
#
# [84 rows x 3 columns]

# %%
# Bước 3: Đặt tên cột cho data frame tạm
df_temp.columns = ['Gender','Lower_hour','Upper_hour']

# %%
df_temp
# Out:
#    Gender Lower_hour Upper_hour
# 0       m         00         06
# 14      m         06         12
# 28      m         12         18
# 42      f         00         06
# 56      f         06         12
# ..    ...        ...        ...
# 27      m         06         12
# 41      m         12         18
# 55      f         00         06
# 69      f         06         12
# 83      f         12         18
#
# [84 rows x 3 columns]

# %%
# Bước 4: Nối data frame tạm vào data frame ban đầu
df = pd.concat([df,df_temp],axis=1)
df
# Out:
#       Id   Age Weight_kgs Firstname Lastname gender_time PulseRate Gender  \
# 0    1.0  56.0         70     Micky     Mous       m0006        72      m
# 14   1.0  56.0         70     Micky     Mous       m0612        69      m
# 28   1.0  56.0         70     Micky     Mous       m1218        71      m
# 42   1.0  56.0         70     Micky     Mous       f0006         -      f
# 56   1.0  56.0         70     Micky     Mous       f0612         -      f
# ..   ...   ...        ...       ...      ...         ...       ...    ...
# 27  15.0  52.0         81       NaN      NaN       m0612         -      m
# 41  15.0  52.0         81       NaN      NaN       m1218         -      m
# 55  15.0  52.0         81       NaN      NaN       f0006        68      f
# 69  15.0  52.0         81       NaN      NaN       f0612        75      f
# 83  15.0  52.0         81       NaN      NaN       f1218        72      f
#
#    Lower_hour Upper_hour
# 0          00         06
# 14         06         12
# 28         12         18
# 42         00         06
# 56         06         12
# ..        ...        ...
# 27         06         12
# 41         12         18
# 55         00         06
# 69         06         12
# 83         12         18
#
# [84 rows x 10 columns]

# %%
# Bước 5: Bỏ cột gender_time
df = df.drop(['gender_time'],axis = 1)
df
# Out:
#       Id   Age Weight_kgs Firstname Lastname PulseRate Gender Lower_hour  \
# 0    1.0  56.0         70     Micky     Mous        72      m         00
# 14   1.0  56.0         70     Micky     Mous        69      m         06
# 28   1.0  56.0         70     Micky     Mous        71      m         12
# 42   1.0  56.0         70     Micky     Mous         -      f         00
# 56   1.0  56.0         70     Micky     Mous         -      f         06
# ..   ...   ...        ...       ...      ...       ...    ...        ...
# 27  15.0  52.0         81       NaN      NaN         -      m         06
# 41  15.0  52.0         81       NaN      NaN         -      m         12
# 55  15.0  52.0         81       NaN      NaN        68      f         00
# 69  15.0  52.0         81       NaN      NaN        75      f         06
# 83  15.0  52.0         81       NaN      NaN        72      f         12
#
#    Upper_hour
# 0          06
# 14         12
# 28         18
# 42         06
# 56         12
# ..        ...
# 27         12
# 41         18
# 55         06
# 69         12
# 83         18
#
# [84 rows x 9 columns]

# %% [markdown]
# 12. Loại bỏ hết các dòng dữ liệu thừa là những dòng có phần PulseRate có dấu -

# %%
import numpy as np

# %%
# Nếu tên cột là 'PulseRate ' với dấu cách ở cuối
df = df.replace('-', np.nan).dropna(subset=['PulseRate'])
df.head(10)
# Out:
#      Id   Age Weight_kgs Firstname Lastname PulseRate Gender Lower_hour  \
# 0   1.0  56.0         70     Micky     Mous        72      m         00
# 14  1.0  56.0         70     Micky     Mous        69      m         06
# 28  1.0  56.0         70     Micky     Mous        71      m         12
# 43  2.0  34.0         70    Donald     Duck        85      f         00
# 57  2.0  34.0         70    Donald     Duck        84      f         06
# 71  2.0  34.0         70    Donald     Duck        76      f         12
# 44  3.0  16.0       74.0      Mini    Mouse        65      f         00
# 58  3.0  16.0       74.0      Mini    Mouse        69      f         06
# 72  3.0  16.0       74.0      Mini    Mouse        72      f         12
# 3   4.0  34.0         78   Scrooge   McDuck        78      m         00
#
#    Upper_hour
# 0          06
# 14         12
# 28         18
# 43         06
# 57         12
# 71         18
# 44         06
# 58         12
# 72         18
# 3          06

# %% [markdown]
# 13. Nhận thấy có những bệnh nhân chưa ghi nhận họ tên (ví lý do nào đó)

# %%
df['Firstname'].isnull().sum()
df['Lastname'].isnull().sum()
df
# Out:
#       Id   Age Weight_kgs Firstname Lastname PulseRate Gender Lower_hour  \
# 0    1.0  56.0         70     Micky     Mous        72      m         00
# 14   1.0  56.0         70     Micky     Mous        69      m         06
# 28   1.0  56.0         70     Micky     Mous        71      m         12
# 43   2.0  34.0         70    Donald     Duck        85      f         00
# 57   2.0  34.0         70    Donald     Duck        84      f         06
# 71   2.0  34.0         70    Donald     Duck        76      f         12
# 44   3.0  16.0       74.0      Mini    Mouse        65      f         00
# 58   3.0  16.0       74.0      Mini    Mouse        69      f         06
# 72   3.0  16.0       74.0      Mini    Mouse        72      f         12
# 3    4.0  34.0         78   Scrooge   McDuck        78      m         00
# 17   4.0  34.0         78   Scrooge   McDuck        79      m         06
# 31   4.0  34.0         78   Scrooge   McDuck        72      m         12
# 46   5.0  54.0         90      Pink  Panther        69      f         00
# 74   5.0  54.0         90      Pink  Panther        75      f         12
# 47   6.0  52.0         85      Huey   McDuck        68      f         00
# 61   6.0  52.0         85      Huey   McDuck        75      f         06
# 75   6.0  52.0         85      Huey   McDuck        72      f         12
# 48   7.0  19.0         56     Dewey   McDuck        71      f         00
# 62   7.0  19.0         56     Dewey   McDuck        78      f         06
# 76   7.0  19.0         56     Dewey   McDuck        75      f         12
# 7    8.0  32.0         78      Scpy      Doo        78      m         00
# 21   8.0  32.0         78      Scpy      Doo        76      m         06
# 35   8.0  32.0         78      Scpy      Doo        75      m         12
# 50  10.0  12.0         45     Louie   McDuck        92      f         00
# 64  10.0  12.0         45     Louie   McDuck        95      f         06
# 78  10.0  12.0         45     Louie   McDuck        87      f         12
# 9   11.0  34.0         60     Henry      Nam        78      m         00
# 23  11.0  34.0         60     Henry      Nam        75      m         06
# 37  11.0  34.0         60     Henry      Nam        72      m         12
# 10  12.0  34.0       74.0    Michel     Long        65      m         00
# 24  12.0  34.0       74.0    Michel     Long        67      m         06
# 38  12.0  34.0       74.0    Michel     Long        55      m         12
# 53  13.0  34.0       74.0      Tana    Ricky        68      f         00
# 67  13.0  34.0       74.0      Tana    Ricky        72      f         06
# 81  13.0  34.0       74.0      Tana    Ricky        70      f         12
# 55  15.0  52.0         81       NaN      NaN        68      f         00
# 69  15.0  52.0         81       NaN      NaN        75      f         06
# 83  15.0  52.0         81       NaN      NaN        72      f         12
#
#    Upper_hour
# 0          06
# 14         12
# 28         18
# 43         06
# 57         12
# 71         18
# 44         06
# 58         12
# 72         18
# 3          06
# 17         12
# 31         18
# 46         06
# 74         18
# 47         06
# 61         12
# 75         18
# 48         06
# 62         12
# 76         18
# 7          06
# 21         12
# 35         18
# 50         06
# 64         12
# 78         18
# 9          06
# 23         12
# 37         18
# 10         06
# 24         12
# 38         18
# 53         06
# 67         12
# 81         18
# 55         06
# 69         12
# 83         18

# %%
# Nhưng giá trị nhịp tim và thời gian đo nhịp tim thì đầy đủ nên dữ liệu quan tâm là trị số
# nhịp tim vẫn dùng được, nên ta thay họ, tên bị thiếu thành Unknown
df['Firstname'].fillna('Unknown', inplace=True)
df['Lastname'].fillna('Unknown', inplace=True)
df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\3737871386.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Firstname'].fillna('Unknown', inplace=True)
# C:\Users\admin\AppData\Local\Temp\ipykernel_800\3737871386.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Lastname'].fillna('Unknown', inplace=True)
#       Id   Age Weight_kgs Firstname Lastname PulseRate Gender Lower_hour  \
# 0    1.0  56.0         70     Micky     Mous        72      m         00
# 14   1.0  56.0         70     Micky     Mous        69      m         06
# 28   1.0  56.0         70     Micky     Mous        71      m         12
# 43   2.0  34.0         70    Donald     Duck        85      f         00
# 57   2.0  34.0         70    Donald     Duck        84      f         06
# 71   2.0  34.0         70    Donald     Duck        76      f         12
# 44   3.0  16.0       74.0      Mini    Mouse        65      f         00
# 58   3.0  16.0       74.0      Mini    Mouse        69      f         06
# 72   3.0  16.0       74.0      Mini    Mouse        72      f         12
# 3    4.0  34.0         78   Scrooge   McDuck        78      m         00
# 17   4.0  34.0         78   Scrooge   McDuck        79      m         06
# 31   4.0  34.0         78   Scrooge   McDuck        72      m         12
# 46   5.0  54.0         90      Pink  Panther        69      f         00
# 74   5.0  54.0         90      Pink  Panther        75      f         12
# 47   6.0  52.0         85      Huey   McDuck        68      f         00
# 61   6.0  52.0         85      Huey   McDuck        75      f         06
# 75   6.0  52.0         85      Huey   McDuck        72      f         12
# 48   7.0  19.0         56     Dewey   McDuck        71      f         00
# 62   7.0  19.0         56     Dewey   McDuck        78      f         06
# 76   7.0  19.0         56     Dewey   McDuck        75      f         12
# 7    8.0  32.0         78      Scpy      Doo        78      m         00
# 21   8.0  32.0         78      Scpy      Doo        76      m         06
# 35   8.0  32.0         78      Scpy      Doo        75      m         12
# 50  10.0  12.0         45     Louie   McDuck        92      f         00
# 64  10.0  12.0         45     Louie   McDuck        95      f         06
# 78  10.0  12.0         45     Louie   McDuck        87      f         12
# 9   11.0  34.0         60     Henry      Nam        78      m         00
# 23  11.0  34.0         60     Henry      Nam        75      m         06
# 37  11.0  34.0         60     Henry      Nam        72      m         12
# 10  12.0  34.0       74.0    Michel     Long        65      m         00
# 24  12.0  34.0       74.0    Michel     Long        67      m         06
# 38  12.0  34.0       74.0    Michel     Long        55      m         12
# 53  13.0  34.0       74.0      Tana    Ricky        68      f         00
# 67  13.0  34.0       74.0      Tana    Ricky        72      f         06
# 81  13.0  34.0       74.0      Tana    Ricky        70      f         12
# 55  15.0  52.0         81   Unknown  Unknown        68      f         00
# 69  15.0  52.0         81   Unknown  Unknown        75      f         06
# 83  15.0  52.0         81   Unknown  Unknown        72      f         12
#
#    Upper_hour
# 0          06
# 14         12
# 28         18
# 43         06
# 57         12
# 71         18
# 44         06
# 58         12
# 72         18
# 3          06
# 17         12
# 31         18
# 46         06
# 74         18
# 47         06
# 61         12
# 75         18
# 48         06
# 62         12
# 76         18
# 7          06
# 21         12
# 35         18
# 50         06
# 64         12
# 78         18
# 9          06
# 23         12
# 37         18
# 10         06
# 24         12
# 38         18
# 53         06
# 67         12
# 81         18
# 55         06
# 69         12
# 83         18

# %% [markdown]
# 14. Sau khi xử lý thì index của dòng dữ liệu đã thay đổi lung tung, ta cần reset index lại cho
# theo khuôn mẫu

# %%
df = df.reset_index()
df
# Out:
#     index    Id   Age Weight_kgs Firstname Lastname PulseRate Gender  \
# 0       0   1.0  56.0         70     Micky     Mous        72      m
# 1      14   1.0  56.0         70     Micky     Mous        69      m
# 2      28   1.0  56.0         70     Micky     Mous        71      m
# 3      43   2.0  34.0         70    Donald     Duck        85      f
# 4      57   2.0  34.0         70    Donald     Duck        84      f
# 5      71   2.0  34.0         70    Donald     Duck        76      f
# 6      44   3.0  16.0       74.0      Mini    Mouse        65      f
# 7      58   3.0  16.0       74.0      Mini    Mouse        69      f
# 8      72   3.0  16.0       74.0      Mini    Mouse        72      f
# 9       3   4.0  34.0         78   Scrooge   McDuck        78      m
# 10     17   4.0  34.0         78   Scrooge   McDuck        79      m
# 11     31   4.0  34.0         78   Scrooge   McDuck        72      m
# 12     46   5.0  54.0         90      Pink  Panther        69      f
# 13     74   5.0  54.0         90      Pink  Panther        75      f
# 14     47   6.0  52.0         85      Huey   McDuck        68      f
# 15     61   6.0  52.0         85      Huey   McDuck        75      f
# 16     75   6.0  52.0         85      Huey   McDuck        72      f
# 17     48   7.0  19.0         56     Dewey   McDuck        71      f
# 18     62   7.0  19.0         56     Dewey   McDuck        78      f
# 19     76   7.0  19.0         56     Dewey   McDuck        75      f
# 20      7   8.0  32.0         78      Scpy      Doo        78      m
# 21     21   8.0  32.0         78      Scpy      Doo        76      m
# 22     35   8.0  32.0         78      Scpy      Doo        75      m
# 23     50  10.0  12.0         45     Louie   McDuck        92      f
# 24     64  10.0  12.0         45     Louie   McDuck        95      f
# 25     78  10.0  12.0         45     Louie   McDuck        87      f
# 26      9  11.0  34.0         60     Henry      Nam        78      m
# 27     23  11.0  34.0         60     Henry      Nam        75      m
# 28     37  11.0  34.0         60     Henry      Nam        72      m
# 29     10  12.0  34.0       74.0    Michel     Long        65      m
# 30     24  12.0  34.0       74.0    Michel     Long        67      m
# 31     38  12.0  34.0       74.0    Michel     Long        55      m
# 32     53  13.0  34.0       74.0      Tana    Ricky        68      f
# 33     67  13.0  34.0       74.0      Tana    Ricky        72      f
# 34     81  13.0  34.0       74.0      Tana    Ricky        70      f
# 35     55  15.0  52.0         81   Unknown  Unknown        68      f
# 36     69  15.0  52.0         81   Unknown  Unknown        75      f
# 37     83  15.0  52.0         81   Unknown  Unknown        72      f
#
#    Lower_hour Upper_hour
# 0          00         06
# 1          06         12
# 2          12         18
# 3          00         06
# 4          06         12
# 5          12         18
# 6          00         06
# 7          06         12
# 8          12         18
# 9          00         06
# 10         06         12
# 11         12         18
# 12         00         06
# 13         12         18
# 14         00         06
# 15         06         12
# 16         12         18
# 17         00         06
# 18         06         12
# 19         12         18
# 20         00         06
# 21         06         12
# 22         12         18
# 23         00         06
# 24         06         12
# 25         12         18
# 26         00         06
# 27         06         12
# 28         12         18
# 29         00         06
# 30         06         12
# 31         12         18
# 32         00         06
# 33         06         12
# 34         12         18
# 35         00         06
# 36         06         12
# 37         12         18

# %% [markdown]
# 15.  Sau đó, lưu trữ dữ liệu đã xử lý thành công với tên file patient_heart_rate_clean.csv

# %%
df.to_csv('patient_heart_rate_clean.csv')
